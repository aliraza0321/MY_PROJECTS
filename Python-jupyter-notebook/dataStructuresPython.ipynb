# %%
#task1
num1=[1,2,3,4,5]
print(sum(num1))
print(num1[0])
print(num2[4])
# Out:
# 15
# 1
# 4

# %%
num2=[1,1,2,2,4,4,5,5,6]
unique=set(num2)
print(list(unique))
# Out:
# [1, 2, 4, 5, 6]

# %%
#task2 
num1=[1,3,5,6,8]
num1.append(9)
num1.remove(5)
#num1.remove(4) gives error because 4 is not in list
print(num1)
# Out:
# [1, 3, 6, 8, 9]

# %%
#task 3
tuple1=(1,2,3,4)
print(tuple1[3])
# Out:
# 4

# %%
#task4
dic={
    "name":"ali",
    "age":19,
    "city":"Lahore"
}
print(dic)
print(dic["city"])
# Out:
# {'name': 'ali', 'age': 19, 'city': 'Lahore'}
# Lahore

# %%
#task 5
numbers=[1,1,2,3,3,3,2,2,3,4,5,6,7,7,9]
print(numbers)
unique=set(numbers)
print(unique)
# Out:
# [1, 1, 2, 3, 3, 3, 2, 2, 3, 4, 5, 6, 7, 7, 9]
# {1, 2, 3, 4, 5, 6, 7, 9}

# %%
#task 6
number=[3,4,2,5,10]
max=numbers[0]
i=1
while i<len(number):#for size of list
    if number[i]>max:
        max=number[i]
    i+=1
print(max)
# Out:
# 10

# %%
#task 7
marks={
    "ali":78,
    "Irtaza":80,
    "Raza":75,
    "haseeb":90
}
max =0;
for i in marks:#is is key of dic that is use to access other values
    if marks[i]>max:
        max=marks[i]
    print(i,marks[i])
    
print(max)
# Out:
# ali 78
# Irtaza 80
# Raza 75
# haseeb 90
# 90
